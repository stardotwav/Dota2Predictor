# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# variável usada para remover warnings do jupyter notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# leitura e transformação do arquivo em dataframe
dados = pd.read_csv('dadospartidaspro.csv')
dados = dados.drop_duplicates()
dados = dados.drop(columns=['Unnamed: 0', 'id'])
dados
# Out:
#        winner  pick1  taxavitoria1  rank1  pick2  taxavitoria2  rank2  pick3  \
# 0     radiant    103         48.71     80    137         47.80     80     40
# 1        dire     48         53.33     52     11         46.33     54    128
# 2        dire     54         46.68     80    120         45.35     80     69
# 3        dire    136         47.02     80     74         48.71     80    108
# 4     radiant     85         53.33     75     25         46.33     75    128
# ...       ...    ...           ...    ...    ...           ...    ...    ...
# 1382  radiant    126         48.22     70     87         49.85     70     96
# 1383  radiant     73         51.31     70     33         49.16     70     85
# 1384  radiant    104         54.35     80    126         48.22     80     75
# 1385     dire     73         51.31     80     94         54.30     70     90
# 1386     dire     64         50.80     70     14         49.12     70     94
#
#       taxavitoria3  rank3  ...  rank7  pick8  taxavitoria8  rank8  pick9  \
# 0            56.34     80  ...     80     32         47.60     80     51
# 1            47.00     45  ...     75     45         46.77     75    105
# 2            43.66     80  ...     80     96         51.74     80     86
# 3            49.49     80  ...     80     46         45.32     80     75
# 4            42.92     75  ...     54    137         47.80     45    110
# ...            ...    ...  ...    ...    ...           ...    ...    ...
# 1382         47.70     70  ...     70     63         48.55     70    138
# 1383         53.33     70  ...     70    129         42.92     70      8
# 1384         52.01     80  ...     80    136         49.49     80     91
# 1385         49.96     80  ...     70     86         48.71     70     87
# 1386         54.30     70  ...     70     57         50.87     70     32
#
#       taxavitoria9  rank9  pick10  taxavitoria10  rank10
# 0            49.86     80      89          54.47      80
# 1            38.84     75      53          51.87      75
# 2            49.88     80      91          51.34      80
# 3            52.01     80      53          38.84      80
# 4            47.90     75       5          45.87      75
# ...            ...    ...     ...            ...     ...
# 1382         48.06     70      89          54.47      70
# 1383         46.56     70     106          49.86      70
# 1384         49.88     80      73          51.31      80
# 1385         49.85     70     120          50.21      70
# 1386         52.82     70      98          48.15      70
#
# [1387 rows x 31 columns]

# %%
# gráfico e valor do número partidas com vitória dire e radiant
sns.set_style('darkgrid')
color = sns.color_palette("rocket")
sns.countplot(x='winner', data=dados, palette=color)
# Out:
# <Axes: xlabel='winner', ylabel='count'>

# %%
print(dados[dados['winner']=='radiant']['winner'].count())
print(dados[dados['winner']=='dire']['winner'].count())
# Out:
# 676
# 711

# %%
# matriz de correlação entre os dados
sns.heatmap(dados.corr())
# Out:
# <Axes: >

# %%
dados['winner'] = dados['winner'].apply(lambda item: 1 if item == 'radiant' else 0)
sns.distplot(dados['rank1'], color='#35193e')
# Out:
# <Axes: xlabel='rank1', ylabel='Density'>

# %%
sns.distplot(dados['rank2'], color='#701f57')
# Out:
# <Axes: xlabel='rank2', ylabel='Density'>

# %%
sns.distplot(dados['pick1'], color='#ad1759')
# Out:
# <Axes: xlabel='pick1', ylabel='Density'>

# %%
sns.distplot(dados['pick5'], color='#e13342')
# Out:
# <Axes: xlabel='pick5', ylabel='Density'>

# %%
ax = plt.subplots()
ax = sns.distplot(dados['pick1'], color='#35193e')
ax = sns.distplot(dados['pick5'], color='#ad1759')
ax.set(xlabel='Número Primeiro Personagem de Cada Time', ylabel='Densidade')
plt.show()

# %%
ax = plt.subplots()
ax = sns.distplot(dados['rank1'], color='#35193e')
ax = sns.distplot(dados['rank5'], color='#ad1759')
ax.set(xlabel='Primeira Medalha de Pessoa Jogadora de Cada Time', ylabel='Densidade')
plt.show()

# %%
dados['pick1'].unique().max()
# Out:
# 137
